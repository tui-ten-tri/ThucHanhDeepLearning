# %% [markdown]
# <a href="https://colab.research.google.com/github/tui-ten-tri/ThucHanhDeepLearning/blob/main/lab1_th_dl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
my_list = [[1.,2., 3.],[4., 5., 6.]]
my_list2 = [[1.,2., 3.]]
my_list3 = [[1.,2., 3.]]
# print(my_list)
np_arr = np.array(my_list)
np_arr2 = np.array(my_list2)
np_arr3 = np.array(my_list3)

# print(np_arr)

# print(np_arr.shape)
# print(np_arr.reshape(3,2))
# print(np_arr.dtype)

# print(np.ones(shape=(2,2)))

# print(np_arr.flatten())

# print(np.hstack((np_arr3, np_arr2)))
# print(np.vstack((np_arr3, np_arr2)))

# print(np.random.rand(3,2,3))

# print(np.random.normal(5,1,10))

# print(np.random.choice([1,2,3], size=(5,5)))
# A = np.matrix(np.ones((5,5)))
# print(A)
# np.array(A)[2] = 2
# np.array(A)[2] = 2
# print(A)

# print(np.arange(1,20,3))

# print(np.linspace(1., 5., num = 20))
# print(np_arr[0], np_arr[:,0])
# Out:
# [1. 2. 3.] [1. 4.]

# %%
import pandas as pd;
a = pd.Series([1,2,3], index=['a','b','c'])
# print(a)
# print(a['a'])
# week = {"t2":"thuhai","t3":"thuba"}
# b = pd.Series(week)
# print(b)
# c = np.array([[1,2],[3,4]])
# df_c = pd.DataFrame(c);
# print(df_c)
# print(np.array(df_c))

# dic = {'name':['nguyen van a', 'nguyen van b'],'age':[10, 20]}
# print(dic)
# df_dic = pd.DataFrame(dic)
# print(df_dic)

d = np.random.randn(20,2);
df_d = pd.DataFrame(d, columns=['so1', 'so2'])
print(df_d)
# Out:
#          so1       so2
# 0   0.151667 -1.156882
# 1  -1.136505 -0.123490
# 2  -1.007869  0.030124
# 3   1.022931  0.203770
# 4  -0.856764 -0.404793
# 5   0.422388 -0.970756
# 6  -0.089311  1.572359
# 7  -0.306887 -0.324052
# 8   0.374080  0.154557
# 9  -0.075688 -0.419563
# 10  0.834642 -0.943357
# 11  0.133463  1.924683
# 12  1.978611  0.362565
# 13  0.212391  0.359656
# 14 -0.397679 -0.097452
# 15 -0.661763 -1.846293
# 16 -0.776997  1.426980
# 17  1.563943 -1.190261
# 18 -0.768493  0.079434
# 19  0.524194  0.863800
